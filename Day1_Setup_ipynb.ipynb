# %% [markdown]
# <a href="https://colab.research.google.com/github/Medapatisanjana12/ai-mentor-portfolio/blob/main/Day1_Setup_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid describes a hierarchy of skills needed to successfully implement and manage AI, from foundational technical work to strategic leadership:
#
# *   **Foundation (Data & ML Development):** The base involves data engineering, collection, cleaning, and core machine learning model building, training, and feature engineering.
# *   **Operationalization (MLOps):** Focuses on deploying, monitoring, maintaining, and scaling AI models reliably in production environments.
# *   **Application (AI Product & Domain Expertise):** Involves understanding business problems, translating them into AI solutions, and managing the product lifecycle with specific industry knowledge.
# *   **Direction (AI Strategy & Leadership):** The top layer, concerning vision setting, governance, ethical considerations, and aligning AI initiatives with overall business goals.
